# %% [markdown]
# # 01 Data Profiling
# Load and explore the Amazon Reviews dataset structure, data types, and quality metrics.

# %%
import pandas as pd
import numpy as np
import json
from pathlib import Path

# Configure paths
DATA_PATH = '../data/Amazon_Reviews.csv'
REPORT_PATH = '../assets/reports/data_profile.json'

print('Loading dataset...')
df = pd.read_csv(DATA_PATH)
print(f'Shape: {df.shape}')
df.head()

# %%
# Data types and missing values
print('Data Types:')
print(df.dtypes)
print('\nMissing Values:')
missing = df.isnull().sum()
print(missing[missing > 0] if missing.sum() > 0 else 'None')
print('\nDataFrame Info:')
df.info()

# %%
# Basic statistics on numeric columns
print('Numeric Column Statistics:')
df.describe()

# %%
# Column-specific profiling
if 'overall' in df.columns:
    print('Rating Distribution:')
    print(df['overall'].value_counts().sort_index())

if 'reviewText' in df.columns:
    print('\nText Length Statistics:')
    text_lens = df['reviewText'].fillna('').str.len()
    print(f'Mean: {text_lens.mean():.0f}, Min: {text_lens.min()}, Max: {text_lens.max()}')

if 'summary' in df.columns:
    print('\nSummary Length Statistics:')
    summary_lens = df['summary'].fillna('').str.len()
    print(f'Mean: {summary_lens.mean():.0f}, Min: {summary_lens.min()}, Max: {summary_lens.max()}')

# %%
# Generate data profile report
profile = {
    'shape': list(df.shape),
    'columns': list(df.columns),
    'dtypes': df.dtypes.astype(str).to_dict(),
    'missing_count': df.isnull().sum().to_dict(),
    'numeric_stats': df.describe().to_dict()
}

Path(REPORT_PATH).parent.mkdir(parents=True, exist_ok=True)
with open(REPORT_PATH, 'w') as f:
    json.dump(profile, f, indent=2, default=str)
    
print(f'Profile saved to {REPORT_PATH}')
